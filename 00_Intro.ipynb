# %% [markdown]
# # Introduction

# %% [markdown]
# <img src="images/software_overview.png" alt="drawing" width="800"/>

# %% [markdown]
# <img src="images/install_python.png" alt="drawing" width="900"/>
#
# If you prefer a Matlab like experience, use the **Spyder IDE**, it comes with Anaconda.
#
# If you like to make a notebook with your code, use **JupyterLabs**

# %% [markdown]
# <img src="images/data_layout.png" alt="drawing" width="1000"/>

# %% [markdown]
# <img src="images/tall_vs_wide.png" alt="drawing" width="1000"/>

# %% [markdown]
# ## Better Example of Tall Format Data
# <img src="images/example_tall.png" alt="drawing" width="750"/>

# %%
import pandas as pd
wide = pd.read_csv('data/dist_v_time.csv')
tall = pd.read_csv('data/dist_v_time_tall.csv')
display(wide)
display(tall)
# Out:
#     Time         S1         S2          S3         S4
# 0      0   0.000000   0.000000    0.000000   0.000000
# 1     10  17.133795  12.195851   21.187260   9.107360
# 2     20  24.027567  17.456237   33.473938   5.187678
# 3     30  29.128881  21.598526   39.134777   8.927878
# 4     40  34.210095  25.909595   41.520706  17.266036
# 5     50  29.891332  26.233662   46.280139  20.506097
# 6     60  37.039804  30.028531   55.344932   8.365644
# 7     70  43.734501  32.992294   61.159848  15.059880
# 8     80  47.242018  34.823032   66.858433  16.994117
# 9     90  54.678656  36.429439   65.411713  20.965901
# 10   100  54.818182  42.200000   67.150000  22.200000
# 11   110  58.828642  41.078347   70.165312  18.039512
# 12   120  46.705796  42.795389   80.131810  28.262484
# 13   130  57.423381  45.112941   75.251578  18.812895
# 14   140  59.268363  44.094515   83.239243  30.881936
# 15   150  53.554753  52.500730   81.200585  22.167882
# ...

# %% [markdown]
# ## Elements of a Figure in Python Matplotlib

# %% [markdown]
# <img src="images/sphx_glr_anatomy_001.png" alt="drawing" width="580"/>
#
# From https://matplotlib.org/3.1.1/gallery/showcase/anatomy.html

# %% [markdown]
# ## Useful References
#
# (Source: http://ehmatthes.github.io/pcc/cheatsheets/README.html)
#
# **Python and Matplotlib**
#
# Python Beginner Cheat Sheet - https://github.com/ehmatthes/pcc/releases/download/v1.0.0/beginners_python_cheat_sheet_pcc.pdf)
#
# Matplotlib (Python plotting) Cheat Sheet - https://github.com/ehmatthes/pcc/releases/download/v1.0.0/beginners_python_cheat_sheet_pcc_matplotlib.pdf
#
#
# **Statistics**
#
# Graphpad overview of statistics and errors: https://www.graphpad.com/guides/prism/latest/statistics/confidence_intervals.htm
